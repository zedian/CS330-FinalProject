# %%
cd ~/Desktop/workbench/cs330-final
# Out:
# /Users/gautam/Desktop/workbench/cs330-final

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import itertools

import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from tqdm import tqdm

import datasets
import model
import utils
import train

# %% [markdown]
# ## Task Setup
# Setup datasets, loss functions, etc.

# %%
bs = 512

is_two_train = datasets.IsNumber(n=2, train=True)
is_five_train = datasets.IsNumber(n=5, train=True)

is_two_val = datasets.IsNumber(n=2, train=False)
is_five_val = datasets.IsNumber(n=5, train=False)

is_two_train_loader = DataLoader(is_two_train, batch_size=bs, shuffle=True, drop_last=True)
is_five_train_loader = DataLoader(is_five_train, batch_size=bs, shuffle=True, drop_last=True)

is2_iter = itertools.cycle(is_two_train_loader)
is5_iter = itertools.cycle(is_five_train_loader)

# %%
tasks = {
    't0': {
        'train_iter': is2_iter,
        'eval_ds': is_two_val,
        'loss': lambda logits, labels: F.binary_cross_entropy_with_logits(logits, labels[..., None]),
        'predict': lambda logits: torch.sigmoid(logits) > 0.5,
        'metric': lambda yh, y: accuracy(yh, y.long().bool()[..., None]),
    },
    't1': {
        'train_iter': is5_iter,
        'eval_ds': is_five_val,
        'loss': lambda logits, labels: F.binary_cross_entropy_with_logits(logits, labels[..., None]),
        'predict': lambda logits: torch.sigmoid(logits) > 0.5,
        'metric': lambda yh, y: accuracy(yh, y.long().bool()[..., None]),
    },
}

# %% [markdown]
# ## Compute gradient alignments

# %%
class SharedMTL(nn.Module):
    def __init__(self, task_keys):
        super().__init__()
        self.backbone = model.LinearBackbone()
        self.heads = nn.ModuleDict({
            task: nn.Linear(256, 1)
            for task in task_keys
        })
    
    def forward(self, x, task):
        return self.heads[task](self.backbone(x)) 


shared_mtl = SharedMTL(tasks.keys())
grads = train.get_gradients(
    model=shared_mtl,
    tasks=tasks, 
    steps=200, 
    lr=3e-4,
)
# Out:
#   0%|                                                                    | 0/200 [00:00<?, ?it/s]
#   3%|█▊                                                          | 6/200 [00:00<00:03, 54.86it/s]
#   7%|████▏                                                      | 14/200 [00:00<00:02, 66.89it/s]
#  12%|███████                                                    | 24/200 [00:00<00:02, 77.58it/s]
#  18%|██████████▎                                                | 35/200 [00:00<00:01, 88.08it/s]
#  23%|█████████████▌                                             | 46/200 [00:00<00:01, 93.10it/s]
#  28%|████████████████▊                                          | 57/200 [00:00<00:01, 98.18it/s]
#  34%|███████████████████▊                                       | 67/200 [00:00<00:01, 98.35it/s]
#  39%|███████████████████████                                    | 78/200 [00:00<00:01, 98.37it/s]
#  44%|█████████████████████████▉                                 | 88/200 [00:00<00:01, 98.78it/s]
#  50%|████████████████████████████▌                            | 100/200 [00:01<00:00, 104.43it/s]
#  56%|███████████████████████████████▉                         | 112/200 [00:01<00:00, 108.30it/s]
#  62%|███████████████████████████████████▎                     | 124/200 [00:01<00:00, 111.57it/s]
#  68%|██████████████████████████████████████▊                  | 136/200 [00:01<00:00, 113.08it/s]
#  74%|██████████████████████████████████████████▏              | 148/200 [00:01<00:00, 114.48it/s]
#  80%|█████████████████████████████████████████████▌           | 160/200 [00:01<00:00, 115.78it/s]
#  86%|█████████████████████████████████████████████████        | 172/200 [00:01<00:00, 115.84it/s]
#  92%|████████████████████████████████████████████████████▍    | 184/200 [00:01<00:00, 116.41it/s]
# 100%|█████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 104.81it/s]

# %%
param_keys = ['backbone.' + k for k in list(shared_mtl.backbone.state_dict().keys())]
print(param_keys)

heuristic_results = {}

# plots
n_rows = 2
n_cols = 3
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 10))

for i, key in enumerate(param_keys):
    # get gradients
    g0 = stack_grad(grads, 't0', key)
    g1 = stack_grad(grads, 't1', key)
    
    # heuristics computations
    cosine = torch.sum(F.normalize(g0, dim=-1) * F.normalize(g1, dim=-1), dim=-1)
    smooth_cos = low_pass_filter(cosine[None], filter_size=10)[0][0]
    
    avg_smoothed_cos = smooth_cos.mean()
    std_cos = cosine.std()
    
    heuristic_results[key] = {'avg_cos': avg_smoothed_cos, 'std_cos': std_cos}
      
    # plot
    row, col = i // n_cols, i % n_cols
    ax = axes[row][col]    
    ax.set_title(key)
    if col == 0:
        ax.set_ylabel('Gradient cosine similarity')
    if row == n_rows - 1:
        ax.set_xlabel('Step')
    ax.set_ylim([-1.1, 1.1])
    ax.plot(cosine, color='teal', alpha=0.2)
    ax.plot(smooth_cos, color='teal')
# Out:
# ['backbone.net.0.weight', 'backbone.net.0.bias', 'backbone.net.2.weight', 'backbone.net.2.bias', 'backbone.net.4.weight', 'backbone.net.4.bias']

# %%
heuristic_results
# Out:
# {'backbone.net.0.weight': {'avg_cos': 0.055701334, 'std_cos': tensor(0.2127)},
#  'backbone.net.0.bias': {'avg_cos': 0.10142583, 'std_cos': tensor(0.3714)},
#  'backbone.net.2.weight': {'avg_cos': 0.055880837, 'std_cos': tensor(0.2850)},
#  'backbone.net.2.bias': {'avg_cos': 0.07913873, 'std_cos': tensor(0.4363)},
#  'backbone.net.4.weight': {'avg_cos': 0.001982077, 'std_cos': tensor(0.1276)},
#  'backbone.net.4.bias': {'avg_cos': -0.0012353057, 'std_cos': tensor(0.1840)}}

# %% [markdown]
# ## Experiments

# %%
mtl = SharedMTL(tasks.keys())
fully_shared_exp = train.train_and_evaluate(
    model=mtl,
    tasks=tasks,
    steps=500,
    lr=1e-4,
    eval_every=50,
)
# Out:
#   0%|                                                                    | 0/500 [00:00<?, ?it/s]
#   0%|                                                            | 1/500 [00:00<01:20,  6.17it/s]
#   3%|█▉                                                         | 16/500 [00:00<00:06, 72.78it/s]
#   6%|███▌                                                      | 31/500 [00:00<00:04, 103.12it/s]
#   9%|█████▎                                                    | 46/500 [00:00<00:03, 119.22it/s]
#  12%|██████▉                                                    | 59/500 [00:01<00:08, 49.45it/s]
#  15%|████████▋                                                  | 74/500 [00:01<00:06, 65.59it/s]
#  18%|██████████▌                                                | 89/500 [00:01<00:05, 81.16it/s]
#  20%|███████████▊                                              | 102/500 [00:01<00:07, 54.47it/s]
#  23%|█████████████▌                                            | 117/500 [00:01<00:05, 68.92it/s]
#  26%|███████████████▎                                          | 132/500 [00:01<00:04, 83.20it/s]
#  29%|█████████████████                                         | 147/500 [00:01<00:03, 96.34it/s]
#  32%|██████████████████▌                                       | 160/500 [00:02<00:04, 72.65it/s]
#  35%|████████████████████▎                                     | 175/500 [00:02<00:03, 86.73it/s]
#  38%|██████████████████████                                    | 190/500 [00:02<00:03, 99.58it/s]
#  41%|███████████████████████▌                                  | 203/500 [00:02<00:03, 77.76it/s]
#  44%|█████████████████████████▎                                | 218/500 [00:02<00:03, 91.43it/s]
#  47%|██████████████████████████▌                              | 233/500 [00:02<00:02, 103.61it/s]
#  50%|████████████████████████████▎                            | 248/500 [00:02<00:02, 114.38it/s]
#  52%|██████████████████████████████▍                           | 262/500 [00:03<00:05, 43.94it/s]
#  55%|████████████████████████████████▏                         | 277/500 [00:03<00:03, 55.92it/s]
#  58%|█████████████████████████████████▊                        | 292/500 [00:03<00:03, 68.92it/s]
#  61%|███████████████████████████████████▍                      | 305/500 [00:04<00:03, 60.76it/s]
#  64%|█████████████████████████████████████                     | 320/500 [00:04<00:02, 74.00it/s]
#  67%|██████████████████████████████████████▊                   | 335/500 [00:04<00:01, 87.36it/s]
#  70%|████████████████████████████████████████▎                 | 348/500 [00:04<00:01, 95.08it/s]
#  72%|█████████████████████████████████████████▉                | 361/500 [00:04<00:01, 77.62it/s]
#  75%|███████████████████████████████████████████▌              | 376/500 [00:04<00:01, 91.56it/s]
#  78%|████████████████████████████████████████████▌            | 391/500 [00:05<00:01, 103.73it/s]
#  81%|██████████████████████████████████████████████▊           | 404/500 [00:05<00:01, 67.60it/s]
#  84%|████████████████████████████████████████████████▌         | 419/500 [00:05<00:00, 81.34it/s]
#  87%|██████████████████████████████████████████████████▏       | 433/500 [00:05<00:00, 92.16it/s]
#  89%|██████████████████████████████████████████████████▊      | 446/500 [00:05<00:00, 100.03it/s]
#  92%|█████████████████████████████████████████████████████▏    | 459/500 [00:05<00:00, 79.78it/s]
#  95%|██████████████████████████████████████████████████████▉   | 474/500 [00:06<00:00, 93.70it/s]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:06<00:00, 80.16it/s]

# %%
class SeparateMTL(nn.Module):
    def __init__(self, task_keys):
        super().__init__()
        self.backbones = nn.ModuleDict({
            task: LinearBackbone()
            for task in task_keys
        })
        self.heads = nn.ModuleDict({
            task: nn.Linear(256, 1)
            for task in task_keys
        })
    
    def forward(self, x, task):
        return self.heads[task](self.backbones[task](x)) 

mtl = SeparateMTL(tasks.keys())
separate_exp = train.train_and_evaluate(
    model=mtl,
    tasks=tasks,
    steps=500,
    lr=1e-4,
    eval_every=50,
)
# Out:
#   0%|                                                                    | 0/500 [00:00<?, ?it/s]
#   0%|                                                            | 1/500 [00:00<01:24,  5.90it/s]
#   3%|█▌                                                         | 13/500 [00:00<00:08, 58.04it/s]
#   5%|███                                                        | 26/500 [00:00<00:05, 84.32it/s]
#   8%|████▌                                                      | 39/500 [00:00<00:04, 98.21it/s]
#  10%|██████                                                     | 51/500 [00:00<00:06, 70.06it/s]
#  13%|███████▍                                                   | 63/500 [00:00<00:05, 81.77it/s]
#  15%|████████▉                                                  | 76/500 [00:00<00:04, 92.42it/s]
#  18%|██████████▎                                               | 89/500 [00:01<00:04, 100.59it/s]
#  20%|███████████▋                                              | 101/500 [00:01<00:05, 75.26it/s]
#  23%|█████████████                                             | 113/500 [00:01<00:04, 84.74it/s]
#  25%|██████████████▌                                           | 126/500 [00:01<00:03, 93.75it/s]
#  28%|███████████████▊                                         | 139/500 [00:01<00:03, 100.73it/s]
#  30%|█████████████████▌                                        | 151/500 [00:01<00:04, 75.98it/s]
#  33%|██████████████████▉                                       | 163/500 [00:01<00:03, 84.62it/s]
#  35%|████████████████████▎                                     | 175/500 [00:02<00:03, 92.65it/s]
#  37%|█████████████████████▋                                    | 187/500 [00:02<00:03, 99.12it/s]
#  40%|██████████████████████▊                                  | 200/500 [00:02<00:02, 105.35it/s]
#  42%|████████████████████████▌                                 | 212/500 [00:02<00:04, 63.06it/s]
#  45%|██████████████████████████                                | 225/500 [00:02<00:03, 74.18it/s]
#  48%|███████████████████████████▌                              | 238/500 [00:02<00:03, 84.25it/s]
#  50%|█████████████████████████████                             | 251/500 [00:03<00:03, 69.78it/s]
#  53%|██████████████████████████████▌                           | 263/500 [00:03<00:02, 79.07it/s]
#  55%|████████████████████████████████                          | 276/500 [00:03<00:02, 88.43it/s]
#  58%|█████████████████████████████████▌                        | 289/500 [00:03<00:02, 96.27it/s]
#  60%|██████████████████████████████████▉                       | 301/500 [00:03<00:02, 74.34it/s]
#  63%|████████████████████████████████████▎                     | 313/500 [00:03<00:02, 83.43it/s]
#  65%|█████████████████████████████████████▊                    | 326/500 [00:03<00:01, 92.56it/s]
#  68%|███████████████████████████████████████▏                  | 338/500 [00:04<00:01, 98.98it/s]
#  70%|████████████████████████████████████████▋                 | 351/500 [00:04<00:01, 76.18it/s]
#  73%|██████████████████████████████████████████                | 363/500 [00:04<00:01, 85.06it/s]
#  75%|███████████████████████████████████████████▌              | 376/500 [00:04<00:01, 93.82it/s]
#  78%|█████████████████████████████████████████████             | 388/500 [00:04<00:01, 99.15it/s]
#  80%|█████████████████████████████████████████████▌           | 400/500 [00:04<00:00, 104.16it/s]
#  82%|███████████████████████████████████████████████▊          | 412/500 [00:04<00:01, 77.18it/s]
#  85%|█████████████████████████████████████████████████▎        | 425/500 [00:05<00:00, 87.04it/s]
#  87%|██████████████████████████████████████████████████▋       | 437/500 [00:05<00:00, 94.42it/s]
#  90%|███████████████████████████████████████████████████▏     | 449/500 [00:05<00:00, 100.73it/s]
#  92%|█████████████████████████████████████████████████████▍    | 461/500 [00:05<00:00, 75.37it/s]
#  95%|██████████████████████████████████████████████████████▊   | 473/500 [00:05<00:00, 84.71it/s]
#  97%|████████████████████████████████████████████████████████▎ | 485/500 [00:05<00:00, 92.74it/s]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 85.96it/s]

# %%
class SurgicalMTL(nn.Module):
    def __init__(self, task_keys):
        super().__init__()
        self.backbone = model.Shareable(
            mdl=LinearBackbone(),
            task_keys=list(task_keys),
            shared_params=['net.0.weight', 'net.0.bias', 'net.2.weight', 'net.2.bias']
        )
        self.heads = nn.ModuleDict({
            task: nn.Linear(256, 1)
            for task in task_keys
        })
    
    def forward(self, x, task):
        return self.heads[task](self.backbone(x, task))

mtl = SurgicalMTL(tasks.keys())
surgical_exp = train.train_and_evaluate(
    model=mtl,
    tasks=tasks,
    steps=500,
    lr=1e-4,
    eval_every=50,
)
# Out:
#   0%|                                                                    | 0/500 [00:00<?, ?it/s]
#
#   0%|                                                            | 1/500 [00:00<01:23,  5.94it/s]
#
#   3%|█▊                                                         | 15/500 [00:00<00:07, 66.61it/s]
#
#   6%|███▍                                                       | 29/500 [00:00<00:04, 95.28it/s]
#
#   9%|█████                                                     | 44/500 [00:00<00:04, 112.40it/s]
#
#  11%|██████▋                                                    | 57/500 [00:00<00:05, 76.55it/s]
#
#  14%|████████▍                                                  | 72/500 [00:00<00:04, 92.42it/s]
#
#  17%|█████████▉                                                | 86/500 [00:00<00:03, 104.21it/s]
#
#  20%|███████████▍                                             | 100/500 [00:01<00:03, 113.17it/s]
#
#  23%|█████████████                                             | 113/500 [00:01<00:04, 84.28it/s]
#
#  26%|██████████████▊                                           | 128/500 [00:01<00:03, 97.14it/s]
#
#  35%|███████████████████▉                                     | 350/1000 [10:43<19:55,  1.84s/it]
#
#
#  31%|█████████████████▉                                        | 155/500 [00:01<00:05, 66.54it/s]
#
#  34%|███████████████████▌                                      | 169/500 [00:01<00:04, 79.31it/s]
#
#  37%|█████████████████████▎                                    | 184/500 [00:02<00:03, 92.16it/s]
#
#  40%|██████████████████████▋                                  | 199/500 [00:02<00:02, 103.25it/s]
#
#  42%|████████████████████████▌                                 | 212/500 [00:02<00:03, 81.58it/s]
#
#  45%|██████████████████████████▎                               | 227/500 [00:02<00:02, 94.15it/s]
#
#  48%|███████████████████████████▌                             | 242/500 [00:02<00:02, 104.94it/s]
#
#  51%|█████████████████████████████▌                            | 255/500 [00:02<00:02, 82.37it/s]
#
#  54%|███████████████████████████████▏                          | 269/500 [00:02<00:02, 93.89it/s]
#
#  57%|████████████████████████████████▎                        | 283/500 [00:03<00:02, 104.15it/s]
#
#  60%|█████████████████████████████████▉                       | 298/500 [00:03<00:01, 113.43it/s]
#
#  62%|████████████████████████████████████                      | 311/500 [00:03<00:02, 85.28it/s]
#
#  65%|█████████████████████████████████████▋                    | 325/500 [00:03<00:01, 96.14it/s]
#
#  68%|██████████████████████████████████████▊                  | 340/500 [00:03<00:01, 106.79it/s]
#
#  71%|████████████████████████████████████████▉                 | 353/500 [00:03<00:01, 82.70it/s]
#
#  74%|██████████████████████████████████████████▋               | 368/500 [00:04<00:01, 95.12it/s]
#
#  76%|███████████████████████████████████████████▌             | 382/500 [00:04<00:01, 105.07it/s]
#
#  79%|█████████████████████████████████████████████▎           | 397/500 [00:04<00:00, 114.31it/s]
#
#  82%|███████████████████████████████████████████████▌          | 410/500 [00:04<00:01, 86.78it/s]
#
#  85%|█████████████████████████████████████████████████▎        | 425/500 [00:04<00:00, 99.68it/s]
#
#  88%|██████████████████████████████████████████████████▏      | 440/500 [00:04<00:00, 110.83it/s]
#
#  91%|████████████████████████████████████████████████████▌     | 453/500 [00:05<00:00, 69.49it/s]
#
#  94%|██████████████████████████████████████████████████████▎   | 468/500 [00:05<00:00, 83.24it/s]
#
#  97%|████████████████████████████████████████████████████████  | 483/500 [00:05<00:00, 96.29it/s]
#
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 93.24it/s]

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

for exp_name, exp in [
    ('shared', fully_shared_exp),
    ('separate', separate_exp),
    ('surgical', surgical_exp),
]:
    losses, metrics, eval_losses, eval_metrics = exp
    for task_name in tasks:
        tl = [(s, l[task_name]) for s, l in losses]
        el = [(s, l[task_name]) for s, l in eval_losses]
        tm = [(s, m[task_name]) for s, m in metrics]
        em = [(s, m[task_name]) for s, m in eval_metrics]
    
        # plot
        ax = axes[0][0]
        tl_x, tl_y = zip(*tl)
        ax.plot(tl_x, tl_y, label=f'{exp_name}_{task_name}')
        ax.set_yscale('log')
        ax.legend()

        ax = axes[0][1]
        el_x, el_y = zip(*el)
        ax.plot(el_x, el_y, label=f'{exp_name}_{task_name}')
        ax.set_yscale('log')
        ax.legend()

        ax = axes[1][0]
        tm_x, tm_y = zip(*tm)
        ax.plot(tm_x, tm_y, label=f'{exp_name}_{task_name}')
        ax.set_ylim([0.96, 0.999])
        ax.legend()

        ax = axes[1][1]
        em_x, em_y = zip(*em)
        ax.plot(em_x, em_y, label=f'{exp_name}_{task_name}')
        ax.set_ylim([0.99, 0.999])
        ax.legend()
# Out:
#  97%|██████████████████████████████████████████████████████▏ | 4835/5000 [01:04<00:01, 90.58it/s]
